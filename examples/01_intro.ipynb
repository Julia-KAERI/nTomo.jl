# %%
using Pkg, Images
# Pkg.activate("/Users/jiyongso/development/Projects/nTomo.jl")
using nTomo

# %%
img = phantom_shepp_logan(256, 64);
p = mat2gray(img)
# save("shepp_logan.png", p)
# p
# Out:
# 384×384 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(5.55112f-17)  …  Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)  …  Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  ⋮                           ⋱
#  Gray{Float32}(5.55112f-17)  …  Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
#  Gray{Float32}(5.55112f-17)     Gray{Float32}(5.55112f-17)
# ...

# %%
size(img)
# Out:
# (384, 384)

# %%
sino1 = radon(img, 0.0:0.3:179.9)
p=mat2gray(sino1)
# save("sinogram.png", p)
# p
# Out:
# 600×384 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)  …  Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  ⋮                                       ⋱
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
#  Gray{Float32}(0.0)  Gray{Float32}(0.0)     Gray{Float32}(0.0)
# ...

# %%
rec=filtered_back_projection(sino1, 0.0:0.3:179.9, 192, "ramp")
p = mat2gray(rec)
# save("reconed.png", p)
# Out:
# 384×384 Array{Gray{Float32},2} with eltype Gray{Float32}:
#  Gray{Float32}(0.114309)  …  Gray{Float32}(0.110509)
#  Gray{Float32}(0.118421)     Gray{Float32}(0.129027)
#  Gray{Float32}(0.124154)     Gray{Float32}(0.11072)
#  Gray{Float32}(0.116468)     Gray{Float32}(0.114077)
#  Gray{Float32}(0.120442)     Gray{Float32}(0.122911)
#  Gray{Float32}(0.114133)  …  Gray{Float32}(0.0978419)
#  Gray{Float32}(0.117033)     Gray{Float32}(0.121107)
#  Gray{Float32}(0.108799)     Gray{Float32}(0.100769)
#  Gray{Float32}(0.119722)     Gray{Float32}(0.122404)
#  Gray{Float32}(0.128816)     Gray{Float32}(0.128683)
#  ⋮                        ⋱
#  Gray{Float32}(0.118972)  …  Gray{Float32}(0.122438)
#  Gray{Float32}(0.118537)     Gray{Float32}(0.118788)
#  Gray{Float32}(0.114527)     Gray{Float32}(0.105272)
#  Gray{Float32}(0.122626)     Gray{Float32}(0.115166)
#  Gray{Float32}(0.107305)     Gray{Float32}(0.122427)
#  Gray{Float32}(0.1228)    …  Gray{Float32}(0.111425)
# ...

# %%
plot
